# %%
# !git clone https://github.com/MoriTomo1229/prog2-nn.git
# Out:
# Cloning into 'prog2-nn'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 41 (delta 12), reused 32 (delta 12), pack-reused 9 (from 1)
# Receiving objects: 100% (41/41), 12.60 MiB | 8.69 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# %cd prog2-nn/
# Out:
# /content/prog2-nn

# %%
# %run train.py
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 9.10MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 207kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.80MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 12.7MB/s]
# Epoch 1/20
#         training loss:  2.131 (14.893s)
#     validation loss: 2.159 (2.022s)
#     training accuracy: 38.653% (13.320s)
#     validation accuracy: 37.750% (2.448s)
# Epoch 2/20
#         training loss:  1.816 (14.606s)
#     validation loss: 1.888 (1.926s)
#     training accuracy: 58.908% (12.393s)
#     validation accuracy: 58.240% (2.062s)
# Epoch 3/20
#         training loss:  1.518 (14.316s)
#     validation loss: 1.524 (2.770s)
#     training accuracy: 61.113% (12.538s)
#     validation accuracy: 60.440% (1.908s)
# Epoch 4/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/prog2-nn/train.py in <module>
#      62
# ...
