# %%
# !git clone https://github.com/MoriTomo1229/prog2-nn.git
# Out:
# Cloning into 'prog2-nn'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 48 (delta 17), reused 36 (delta 14), pack-reused 9 (from 1)
# Receiving objects: 100% (48/48), 12.60 MiB | 16.96 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd prog2-nn/
# Out:
# /content/prog2-nn

# %%
# %run train.py
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 11.4MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 205kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.80MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 20.1MB/s]
# Using device: cuda
# Epoch 1/20
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/prog2-nn/train.py in <module>
#      68
#      69     time_start = time.time()
# ---> 70     train_loss = models.train(model, dataloader_train, loss_fm, optimizer)
#      71     time_end = time.time()
#      72     print(f'        training loss:  {train_loss:.3f} ({time_end-time_start:.3f}s)')
#
# /content/prog2-nn/models.py in train(model, dataloader, loss_fn, optimizer)
#      47     last_loss = None
#      48     for image_batch, label_batch in dataloader:
# ---> 49         logits_batch = model(image_batch)
#      50         loss = loss_fn(logits_batch, label_batch)
# ...
